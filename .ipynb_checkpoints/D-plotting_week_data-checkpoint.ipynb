# %%
library(ggplot2)

# %%
df <- read.csv("/media/igna/Data/CRI_IA/Teacher_to_teacher/time_data.csv")

# %%
dim(df)
# Out:
# [1] 676757     10

# %%
head(df)
# Out:
#   X author  date_message        forum_name    nb_messages
# 1 0 blanc78 2010-02-23 16:46:05 Mathématiques 18 messages
# 2 1 Yaka... 2010-02-10 17:36:40 Mathématiques 3 517 messages
# 3 2 elodieh 2010-02-21 11:39:24 Mathématiques 73 messages
# 4 3 cdkm    2010-02-21 11:52:19 Mathématiques 662 messages
# 5 4 Stefan  2010-02-21 17:16:09 Mathématiques 2 529 messages
# 6 5 valou44 2010-02-22 11:03:59 Mathématiques 417 messages
#   topic_name                year month weekday day
# 1 la droite graduée au ce1  2010 2     1       23
# 2 Symétrie au cm1           2010 2     2       10
# 3 Symétrie au cm1           2010 2     6       21
# 4 Symétrie au cm1           2010 2     6       21
# 5 Symétrie au cm1           2010 2     6       21
# 6 Symétrie au cm1           2010 2     0       22

# %%
dw <- do.call('rbind',tapply(df$weekday[df$year==2010],df$month[df$year==2010],
                       function(x){
                           data.frame(table(x))}))

# %%
dw$month <- rownames(dw)

# %%
dw$month <- as.numeric(sapply(strsplit(dw$month,".",fixed=TRUE),function(x){x[1]}))

# %%
ggplot(data=dw, aes(x=month, fill=x, y=Freq)) +
    geom_bar(stat="identity", position=position_dodge())
# Out:
# plot without title

# %%
df$date_day <- paste(df$year,df$month,df$day)

# %%
dde = data.frame(table(df$date_day[df$year==2010]))

# %%
plot(c(1,nrow(dde)), c(0,max(dde$Freq)), type="n", xlab="day",
   ylab="Number of posts per day" )
lines(dde)
# Out:
# plot without title

# %% [markdown]
# ## First post of a member
#
# - Was it the creation of a new topic, or not?
# - Creation of new topic vs not creation of a new topic vs timerange of activity

# %%
df$date_message <- as.POSIXlt(df$date_message)

# %%
min(df$date_message[df$author=="--- claire"])
# Out:
# [1] "2012-05-21 15:22:27 CEST"

# %%
df[df$author=="--- claire" & df$date_message==min(df$date_message[df$author=="--- claire"]),]
# Out:
#        X      author     date_message        forum_name    nb_messages
# 215189 215188 --- claire 2012-05-21 15:22:27 Mathématiques 2 messages
#        topic_name                                              year month
# 215189 encadrer une fraction par deux entiers consécutifs cm2  2012 5
#        weekday day date_day
# 215189 0       21  2012 5 21

# %%
dmin_auth <- df[order(df$author,df$date_message),]

# %%
dmin_auth <- dmin_auth[!duplicated(dmin_auth$author),]

# %%
dmin_top <- df[order(df$topic,df$date_message),]
dmin_top <- dmin_top[!duplicated(dmin_top$topic),]

# %%
head(dmin_top)
# Out:
#        X      author   date_message
# 387114 387113 cleb72   2010-04-14 17:29:30
# 469598 469597 Lilied94 2006-12-13 16:06:10
# 436068 436067 48clau   2016-11-09 17:35:56
# 631012 631011 sofy4    2006-04-03 18:35:16
# 488584 488583 puce38   2006-08-09 09:37:06
# 148419 148418 Soleille 2006-05-20 12:46:26
#        forum_name                                             nb_messages
# 387114 Sciences et technologies                               238 messages
# 469598 Organiser, préparer et gérer une classe en élémentaire 58 messages
# 436068 Sciences et technologies                               164 messages
# 631012 Thèmes et projets pour l'élémentaire                   304 messages
# 488584 Français                                               713 messages
# 148419 Musique                                                4 762 messages
#        topic_name
# 387114 - La rotation de la Terre sur elle-même et ses conséquences, la durée
# 469598 ;) Help, please
# 436068 :scratch: Guide du maitre Odysseo sciences CE2
# 631012 !projet autour du jeu de société
# 488584 ? lecture cp: albums école des loisirs
# 148419 ..
#        year month weekday day date_day
# 387114 2010  4    2       14  2010 4 14
# 469598 2006 12    2       13  2006 12 13
# 436068 2016 11    2        9  2016 11 9
# 631012 2006  4    0        3  2006 4 3
# 488584 2006  8    2        9  2006 8 9
# 148419 2006  5    5       20  2006 5 20

# %%
nrow(dmin_auth)
# Out:
# [1] 21559

# %%
table(paste(dmin_auth$author,dmin_auth$date_message,dmin_auth$topic_name)%in%
      paste(dmin_top$author,dmin_top$date_message,dmin_top$topic_name))
# Out:
# FALSE  TRUE
# 15686  5873

# %%
dmin_auth$Was1stMess_newtopic <- paste(dmin_auth$author,dmin_auth$date_message,dmin_auth$topic_name)%in%
                                 paste(dmin_top$author,dmin_top$date_message,dmin_top$topic_name)

# %%
names(dmin_auth)
# Out:
#  [1] "X"                   "author"              "date_message"
#  [4] "forum_name"          "nb_messages"         "topic_name"
#  [7] "year"                "month"               "weekday"
# [10] "day"                 "date_day"            "Was1stMess_newtopic"

# %%
dmax_auth <- df[order(df$author,-as.numeric(df$date_message)),]
dmax_auth <- dmax_auth[!duplicated(dmax_auth$author),]

# %%
dmin_auth$max_date <- dmax_auth$date_message
dmin_auth$max_min <- dmin_auth$max_date - dmin_auth$date_message

# %%
head(dmin_auth$max_min)
# Out:
# Time differences in secs
# [1]    524096    193972  34009260        90 246554340  12982126

# %%
head(as.numeric(dmin_auth$max_min))
# Out:
# [1]    524096    193972  34009260        90 246554340  12982126

# %%
#Time_difference in years
dmin_auth$max_min <- as.numeric(dmin_auth$max_min)/(60*60*24*365)

# %%
table(dmin_auth$Was1stMess_newtopic[trunc(dmin_auth$max_min)==0])/sum(trunc(dmin_auth$max_min)==0)*100
table(dmin_auth$Was1stMess_newtopic[trunc(dmin_auth$max_min)>0])/sum(trunc(dmin_auth$max_min)>0)*100
# Out:
#    FALSE     TRUE
# 73.90988 26.09012
#    FALSE     TRUE
# 70.72702 29.27298

# %% [markdown]
# ### Was first message posted in Jul-Aug --> staying longer in the forum?

# %%
names(dmin_auth)
# Out:
#  [1] "X"                   "author"              "date_message"
#  [4] "forum_name"          "nb_messages"         "topic_name"
#  [7] "year"                "month"               "weekday"
# [10] "day"                 "date_day"            "Was1stMess_newtopic"
# [13] "max_date"            "max_min"

# %%
table((dmin_auth$month%in%c(7,8))[trunc(dmin_auth$max_min)==0])/sum(trunc(dmin_auth$max_min)==0)*100
table((dmin_auth$month%in%c(7,8))[trunc(dmin_auth$max_min)>0])/sum(trunc(dmin_auth$max_min)>0)*100
# Out:
#    FALSE     TRUE
# 69.71657 30.28343
#    FALSE     TRUE
# 70.23977 29.76023

# %%
head(table(df$author))
# Out:
#     _michel       _Robi    - NouN -  --- claire --anonyme--   -Anonyme-
#           4           8          19           2         119           2

# %%
dmin_auth$tot_nb_messages <- as.numeric(table(df$author))

# %%
#mean number of posts per year
ddd <- 
as.numeric(tapply(df$year,df$author,function(x){
    mean(table(as.numeric(x)))
}))

# %%
length(ddd)
# Out:
# [1] 21559

# %%
dmin_auth$mean_posts_year <- ddd

# %%
plot(dmin_auth$max_min,dmin_auth$mean_posts_year,log="y")
# Out:
# plot without title
